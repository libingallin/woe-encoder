# %%
import os
import sys

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
sys.path.append('/Users/libing/codes/woe-encoder/')
# sys.path.append('/Users/bingli/codes/woe-encoder/')

# %%
from sklearn.datasets import load_boston

bunch = load_boston()
data = pd.DataFrame(bunch.data, columns=bunch.feature_names)
y = bunch.target > 22.5
data['y'] = y

continous_feature = 'CRIM'

# %%
from woe_encoder import ContinuousWOEEncoder

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT      y
# 0     15.3  396.90   4.98   True
# 1     17.8  396.90   9.14  False
# 2     17.8  392.83   4.03   True
# 3     18.7  394.63   2.94   True
# 4     18.7  396.90   5.33   True

# %% [markdown]
# **不管使用哪一种分箱方法，`col_name` 和 `target_col_name` 都是要必须指定的参数。**

# %%
encoder = ContinuousWOEEncoder(
    col_name=continous_feature,
    target_col_name='y')
encoder.fit(data)
# Out:
# ContinuousWOEEncoder(col_name='CRIM', target_col_name='y')

# %% [markdown]
# # 1 基于阈值的卡方分箱法（默认）

# %%
encoder = ContinuousWOEEncoder(
    col_name=continous_feature,
    target_col_name='y',
    bin_pct_threshold=0.05,    # default
    woe_method='chi2',         # default
    min_chi2_flag=True,        # default
)
data_transformed = encoder.fit_transform(data)
data_transformed.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT      y  CRIM_woe
# 501     21.0  391.99   9.67  False  1.113558
# 502     21.0  396.90   9.08  False  1.113558
# 503     21.0  396.90   5.64   True  1.113558
# 504     21.0  393.45   6.48  False  0.120051
# 505     21.0  396.90   7.88  False  1.113558

# %%
encoder.bin_result_
# Out:
#    left_exclusive  right_inclusive  good_num  bad_num  bad_rate       woe  \
# 0            -inf          0.09266      46.0    100.0  0.684932  1.113558
# 1         0.09266          0.62356      92.0     73.0  0.442424  0.120051
# 2         0.62356          5.82401      71.0     30.0  0.297030 -0.494093
# 3         5.82401              inf      88.0      6.0  0.063830 -2.194141
#
#          iv
# 0  0.360333
# 1  0.004744
# 2  0.047194
# 3  0.587126

# %%
encoder.iv_
# Out:
# 0.9993971114646631

# %% [markdown]
# # 2. 基于最大分箱数的卡方分箱法

# %% [markdown]
# **参数：**
#
# - `max_bins=10`
#
#
# - `woe_method='chi2'`
#
#
# - `min_chi2_flag=False`

# %%
# 基于最大分箱数的卡方分箱法
encoder = ContinuousWOEEncoder(
    col_name=continous_feature,
    target_col_name='y',
    max_bins=3,                # for illustration
    bin_pct_threshold=0.05,    # default
    woe_method='chi2',
    min_chi2_flag=False,
)
data_transformed = encoder.fit_transform(data)
data_transformed.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT      y  CRIM_woe
# 501     21.0  391.99   9.67  False  1.113558
# 502     21.0  396.90   9.08  False  1.113558
# 503     21.0  396.90   5.64   True  1.113558
# 504     21.0  393.45   6.48  False -0.106890
# 505     21.0  396.90   7.88  False  1.113558

# %%
encoder.bin_result_
# Out:
#    left_exclusive  right_inclusive  good_num  bad_num  bad_rate       woe  \
# 0            -inf          0.09266      46.0    100.0  0.684932  1.113558
# 1         0.09266          5.82401     163.0    103.0  0.387218 -0.106890
# 2         5.82401              inf      88.0      6.0  0.063830 -2.194141
#
#          iv
# 0  0.360333
# 1  0.005986
# 2  0.587126

# %%
encoder.iv_
# Out:
# 0.953444515916242

# %% [markdown]
# # 3. 基于最大分箱数的坏样本率差异最大化分箱方法

# %% [markdown]
# **参数：**
#
# - `max_bins=10`
#
#
# - `woe_method='chi2'`
#
#
# - `min_chi2_flag=False`

# %%
# 基于最大分箱数的坏样本率差异最大化分箱方法
encoder = ContinuousWOEEncoder(
    col_name=continous_feature,
    target_col_name='y',
    max_bins=5,                # just for illustration
    bin_pct_threshold=0.05,    # default
    woe_method='bad_rate',
)
data_transformed = encoder.fit_transform(data)
data_transformed.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT      y  CRIM_woe
# 501     21.0  391.99   9.67  False  0.473289
# 502     21.0  396.90   9.08  False  0.473289
# 503     21.0  396.90   5.64   True  0.473289
# 504     21.0  393.45   6.48  False  0.473289
# 505     21.0  396.90   7.88  False  0.473289

# %%
encoder.bin_result_
# Out:
#    left_exclusive  right_inclusive  good_num  bad_num  bad_rate       woe  \
# 0            -inf          0.32982     127.0    144.0  0.531365  0.473289
# 1         0.32982              inf     170.0     65.0  0.276596 -0.603423
#
#          iv
# 0  0.123711
# 1  0.157726

# %%
encoder.iv_
# Out:
# 0.2814372908278145

# %%
# 基于最大分箱数的坏样本率差异最大化分箱方法
encoder = ContinuousWOEEncoder(
    col_name=continous_feature,
    target_col_name='y',
    max_bins=3,                # just for illustration
    bin_pct_threshold=0.05,    # default
    woe_method='bad_rate',
)
data_transformed = encoder.fit_transform(data)
data_transformed.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT      y  CRIM_woe
# 501     21.0  391.99   9.67  False -0.001401
# 502     21.0  396.90   9.08  False -0.001401
# 503     21.0  396.90   5.64   True -0.001401
# 504     21.0  393.45   6.48  False -0.001401
# 505     21.0  396.90   7.88  False -0.001401

# %%
encoder.bin_result_
# Out:
#    left_exclusive  right_inclusive  good_num  bad_num  bad_rate       woe   iv
# 0            -inf              inf     297.0    209.0  0.413043 -0.001401 -0.0

# %% [markdown]
# # 4. 特殊值与缺失值

# %% [markdown]
# - <font color='crimson'>如果特征中含有需要特殊对待的一个/多个值，可以单独作为一个/多个 bin 处理。</font>
#
#
# - <font color='crimson'>如果特征中含有缺失值，可以将缺失值单独作为一个 bin 来处理，你只需要指定一个不会引起混淆的值来 fill 缺失值。</font>
#
# <br>
#
# **参数：**
#
# - `special_value_list=[value_1]` or `special_value_list=[value_1, value_2]`
#
#
#
# - `imputation_value=xxxx`
#
# <br>
#
# 以下使用【基于最大分箱数的卡方分箱法】来介绍这里的功能。

# %%
# 一个缺失值
encoder = ContinuousWOEEncoder(
    col_name=continous_feature,
    target_col_name='y',
    max_bins=6,                # for illustration
    bin_pct_threshold=0.05,    # default
    woe_method='chi2',
    min_chi2_flag=False,
    special_value_list=[0.01501]
)
data_transformed = encoder.fit_transform(data)
data_transformed.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT      y  CRIM_woe
# 501     21.0  391.99   9.67  False  1.093558
# 502     21.0  396.90   9.08  False  1.093558
# 503     21.0  396.90   5.64   True  1.093558
# 504     21.0  393.45   6.48  False  0.120051
# 505     21.0  396.90   7.88  False  1.093558

# %%
encoder.bin_result_
# Out:
#    left_exclusive  right_inclusive good_num bad_num   bad_rate       woe  \
# 0            -inf          0.09266       46      98   0.680556  1.093558
# 1         0.09266          0.62356       92      73   0.442424  0.120051
# 2         0.62356          5.82401       71      30    0.29703 -0.494093
# 3         5.82401              inf       88       6  0.0638298 -2.194141
# 4         0.01501          0.01501        0       2          1  1.447198
#
#          iv
# 0  0.343396
# 1  0.004744
# 2  0.047194
# 3  0.587126
# 4  0.013849

# %%
# 多个缺失值
encoder = ContinuousWOEEncoder(
    col_name=continous_feature,
    target_col_name='y',
    max_bins=6,                # for illustration
    bin_pct_threshold=0.05,    # default
    woe_method='chi2',
    min_chi2_flag=False,
    special_value_list=[0.01501, 14.33370]
)
data_transformed = encoder.fit_transform(data)
data_transformed.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT      y  CRIM_woe
# 501     21.0  391.99   9.67  False  1.093558
# 502     21.0  396.90   9.08  False  1.093558
# 503     21.0  396.90   5.64   True  1.093558
# 504     21.0  393.45   6.48  False  0.120051
# 505     21.0  396.90   7.88  False  1.093558

# %%
encoder.bin_result_
# Out:
#    left_exclusive  right_inclusive good_num bad_num   bad_rate       woe  \
# 0            -inf          0.09266       46      98   0.680556  1.093558
# 1         0.09266          0.62356       92      73   0.442424  0.120051
# 2         0.62356          5.82401       71      30    0.29703 -0.494093
# 3         5.82401              inf       86       6  0.0652174 -2.171413
# 4         0.01501          0.01501        0       2          1  1.447198
# 5        14.33370         14.33370        2       0          0 -0.750027
#
#          iv
# 0  0.343396
# 1  0.004744
# 2  0.047194
# 3  0.566422
# 4  0.013849
# 5  0.005051

# %%
data_transformed.loc[
    data_transformed[continous_feature].isin((0.01501, 14.3337)),
    [continous_feature, continous_feature+'_woe']]
# Out:
#          CRIM  CRIM_woe
# 283   0.01501  1.447198
# 348   0.01501  1.447198
# 388  14.33370 -0.750027
# 479  14.33370 -0.750027

# %%
# 生成缺失值
data[continous_feature] = data[continous_feature].where(
    data[continous_feature] < 5.8, np.nan)
data.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     410 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  y        506 non-null    bool
# dtypes: bool(1), float64(13)
# memory usage: 52.0 KB

# %%
# 缺失值处理
encoder = ContinuousWOEEncoder(
    col_name=continous_feature,
    target_col_name='y',
    max_bins=6,                # for illustration
    bin_pct_threshold=0.05,    # default
    woe_method='chi2',
    min_chi2_flag=False,
    imputation_value=10000.,
)
data_transformed = encoder.fit_transform(data)
data_transformed.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT      y  CRIM_woe
# 501     21.0  391.99   9.67  False  1.113558
# 502     21.0  396.90   9.08  False  1.113558
# 503     21.0  396.90   5.64   True  1.113558
# 504     21.0  393.45   6.48  False  0.120051
# 505     21.0  396.90   7.88  False  1.113558

# %%
encoder.bin_result_
# Out:
#    left_exclusive  right_inclusive  good_num  bad_num  bad_rate       woe  \
# 0            -inf          0.09266      46.0    100.0  0.684932  1.113558
# 1         0.09266          0.62356      92.0     73.0  0.442424  0.120051
# 2         0.62356              inf      70.0     29.0  0.292929 -0.512897
# 3     10000.00000      10000.00000      89.0      7.0  0.072917 -2.071783
#
#          iv
# 0  0.360333
# 1  0.004744
# 2  0.049717
# 3  0.551447

# %%
data_transformed.loc[data_transformed[continous_feature].isnull(),
                     [continous_feature, continous_feature+'_woe']].head()
# Out:
#      CRIM  CRIM_woe
# 356   NaN -2.071783
# 367   NaN -2.071783
# 370   NaN -2.071783
# 371   NaN -2.071783
# 372   NaN -2.071783

# %%
# 缺失值 + 特殊值
encoder = ContinuousWOEEncoder(
    col_name=continous_feature,
    target_col_name='y',
    max_bins=6,                # for illustration
    bin_pct_threshold=0.05,    # default
    woe_method='chi2',
    min_chi2_flag=False,
    imputation_value=10000.,
    special_value_list=[0.01501]
)
data_transformed = encoder.fit_transform(data)
data_transformed.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT      y  CRIM_woe
# 501     21.0  391.99   9.67  False  1.093558
# 502     21.0  396.90   9.08  False  1.093558
# 503     21.0  396.90   5.64   True  1.093558
# 504     21.0  393.45   6.48  False  0.120051
# 505     21.0  396.90   7.88  False  1.093558

# %%
encoder.bin_result_
# Out:
#    left_exclusive  right_inclusive good_num bad_num   bad_rate       woe  \
# 0            -inf          0.09266       46      98   0.680556  1.093558
# 1         0.09266          0.62356       92      73   0.442424  0.120051
# 2         0.62356              inf       70      29   0.292929 -0.512897
# 3         0.01501          0.01501        0       2          1  1.447198
# 4     10000.00000      10000.00000       89       7  0.0729167 -2.071783
#
#          iv
# 0  0.343396
# 1  0.004744
# 2  0.049717
# 3  0.013849
# 4  0.551447

# %%
data_transformed.loc[
    data_transformed[continous_feature].isnull() | data_transformed[continous_feature].isin([0.01501]),
    [continous_feature, continous_feature+'_woe']
].head()
# Out:
#         CRIM  CRIM_woe
# 283  0.01501  1.447198
# 348  0.01501  1.447198
# 356      NaN -2.071783
# 367      NaN -2.071783
# 370      NaN -2.071783

# %% [markdown]
# # 5. 单调性

# %% [markdown]
# 因为业务需要，有的特征转换之后需要满足单调性（或者符合 U 型）。
#
#
# **参数：**
#
# - `need_monotonic=True`
#
#
#
# - `u=True `

# %%
bunch = load_boston()
data = pd.DataFrame(bunch.data, columns=bunch.feature_names)
y = bunch.target > 22.5
data['y'] = y

continous_feature = 'CRIM'

# %%
# 单调性
encoder = ContinuousWOEEncoder(
    col_name=continous_feature,
    target_col_name='y',
    max_bins=3,                # for illustration
    bin_pct_threshold=0.05,    # default
    woe_method='chi2',
    min_chi2_flag=False,
    need_monotonic=True,
)
data_transformed = encoder.fit_transform(data)
data_transformed.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT      y  CRIM_woe
# 501     21.0  391.99   9.67  False  1.113558
# 502     21.0  396.90   9.08  False  1.113558
# 503     21.0  396.90   5.64   True  1.113558
# 504     21.0  393.45   6.48  False -0.106890
# 505     21.0  396.90   7.88  False  1.113558

# %%
encoder.bin_result_
# Out:
#    left_exclusive  right_inclusive  good_num  bad_num  bad_rate       woe  \
# 0            -inf          0.09266      46.0    100.0  0.684932  1.113558
# 1         0.09266          5.82401     163.0    103.0  0.387218 -0.106890
# 2         5.82401              inf      88.0      6.0  0.063830 -2.194141
#
#          iv
# 0  0.360333
# 1  0.005986
# 2  0.587126

# %%
# U 型
encoder = ContinuousWOEEncoder(
    col_name=continous_feature,
    target_col_name='y',
    max_bins=3,                # for illustration
    bin_pct_threshold=0.05,    # default
    woe_method='chi2',
    min_chi2_flag=False,
    need_monotonic=True,       # must 
    u=True                     # must
)
data_transformed = encoder.fit_transform(data)
data_transformed.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT      y  CRIM_woe
# 501     21.0  391.99   9.67  False  1.113558
# 502     21.0  396.90   9.08  False  1.113558
# 503     21.0  396.90   5.64   True  1.113558
# 504     21.0  393.45   6.48  False -0.106890
# 505     21.0  396.90   7.88  False  1.113558

# %%
encoder.bin_result_
# Out:
#    left_exclusive  right_inclusive  good_num  bad_num  bad_rate       woe  \
# 0            -inf          0.09266      46.0    100.0  0.684932  1.113558
# 1         0.09266          5.82401     163.0    103.0  0.387218 -0.106890
# 2         5.82401              inf      88.0      6.0  0.063830 -2.194141
#
#          iv
# 0  0.360333
# 1  0.005986
# 2  0.587126
